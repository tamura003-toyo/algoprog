# %%
library(boot)
install.packages("bayesm")
# Out:
# Installing package into '/Users/tam/Library/R/arm64/4.4/library'
# (as 'lib' is unspecified)
#
# also installing the dependency 'RcppArmadillo'
# The downloaded binary packages are in
# 	/var/folders/xp/w34p9zps39s245_19pm5w6cr0000gn/T//RtmpbFUcXZ/downloaded_packages

# %%
# サンプルデータの作成
data <- data.frame(
    x = c(1, 2, 3, 4, 5),
    y = c(2, 4, 5, 4, 5)
)

# 線形回帰モデルの作成
model <- lm(y ~ x, data = data)

# 結果の表示
summary(model)
plot(model)
# Out:
# Call:
# lm(formula = y ~ x, data = data)
#
# Residuals:
#    1    2    3    4    5
# -0.8  0.6  1.0 -0.6 -0.2
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   2.2000     0.9381   2.345    0.101
# x             0.6000     0.2828   2.121    0.124
#
# Residual standard error: 0.8944 on 3 degrees of freedom
# Multiple R-squared:    0.6,	Adjusted R-squared:  0.4667
# F-statistic:   4.5 on 1 and 3 DF,  p-value: 0.124
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
