# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# データセットを読み込み（seabornのサンプルデータ）
data = sns.load_dataset("tips")

# 説明変数と目的変数を選択
X = data[["total_bill"]]   # 説明変数
y = data["tip"]            # 目的変数

# モデルを作成・学習
model = LinearRegression()
model.fit(X, y)

# 回帰直線を予測
x_range = np.linspace(X.min(), X.max(), 100)
y_pred = model.predict(x_range)

# 散布図と回帰直線を描画
sns.scatterplot(x="total_bill", y="tip", data=data, color="blue", alpha=0.5)
plt.plot(x_range, y_pred, color="red")
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Linear Regression Example")
plt.show()

# 回帰係数を出力
print("切片:", model.intercept_)
print("傾き:", model.coef_[0])
# Out:
# /Users/Shared/miniforge3/envs/ds/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 切片: 0.920269613554674
# 傾き: 0.10502451738435332
